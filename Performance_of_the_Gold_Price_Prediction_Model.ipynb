# %% [markdown]
# <a href="https://colab.research.google.com/github/Samyuktha2675/AI---Powered-Anlaytics-Internship/blob/main/Performance_of_the_Gold_Price_Prediction_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_percentage_error
import tensorflow as tf
from keras import Model
from keras.layers import Input, Dense, Dropout
from keras.layers import LSTM

# %%
df = pd.read_csv(r"/content/Gold Price (2013-2023).csv")

# %%
df
# Out:
#             Date     Price      Open      High       Low     Vol. Change %
# 0     12/30/2022  1,826.20  1,821.80  1,832.40  1,819.80  107.50K    0.01%
# 1     12/29/2022  1,826.00  1,812.30  1,827.30  1,811.20  105.99K    0.56%
# 2     12/28/2022  1,815.80  1,822.40  1,822.80  1,804.20  118.08K   -0.40%
# 3     12/27/2022  1,823.10  1,808.20  1,841.90  1,808.00  159.62K    0.74%
# 4     12/26/2022  1,809.70  1,805.80  1,811.95  1,805.55      NaN    0.30%
# ...          ...       ...       ...       ...       ...      ...      ...
# 2578  01/08/2013  1,663.20  1,651.50  1,662.60  1,648.80    0.13K    0.97%
# 2579  01/07/2013  1,647.20  1,657.30  1,663.80  1,645.30    0.09K   -0.16%
# 2580  01/04/2013  1,649.90  1,664.40  1,664.40  1,630.00    0.31K   -1.53%
# 2581  01/03/2013  1,675.60  1,688.00  1,689.30  1,664.30    0.19K   -0.85%
# 2582  01/02/2013  1,689.90  1,675.80  1,695.00  1,672.10    0.06K    0.78%
#
# [2583 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2583 entries, 0 to 2582
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      2583 non-null   object
#  1   Price     2583 non-null   object
#  2   Open      2583 non-null   object
#  3   High      2583 non-null   object
#  4   Low       2583 non-null   object
#  5   Vol.      2578 non-null   object
#  6   Change %  2583 non-null   object
# dtypes: object(7)
# memory usage: 141.4+ KB

# %%
df.drop(['Vol.', 'Change %'], axis=1, inplace=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values(by='Date', ascending=True, inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
NumCols = df.columns.drop(['Date'])
df[NumCols] = df[NumCols].replace({',': ''}, regex=True)
df[NumCols] = df[NumCols].astype('float64')

# %%
df.head()
# Out:
#         Date   Price    Open    High     Low
# 0 2013-01-02  1689.9  1675.8  1695.0  1672.1
# 1 2013-01-03  1675.6  1688.0  1689.3  1664.3
# 2 2013-01-04  1649.9  1664.4  1664.4  1630.0
# 3 2013-01-07  1647.2  1657.3  1663.8  1645.3
# 4 2013-01-08  1663.2  1651.5  1662.6  1648.8

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
fig = px.line(y=df.Price, x=df.Date)
fig.update_traces(line_color='black')
fig.update_layout(xaxis_title="Date",
                  yaxis_title="Scaled Price",
                  title={'text': "Gold Price History Data", 'y':0.95, 'x':0.5, 'xanchor':'center', 'yanchor':'top'},
                  plot_bgcolor='rgba(129, 129, 129, 0.6)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="97f3d799-ab58-4ec5-9c43-1e8cbe63a630" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("97f3d799-ab58-4ec5-9c43-1e8cbe63a630")) {                    Plotly.newPlot(                        "97f3d799-ab58-4ec5-9c43-1e8cbe63a630",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"black","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","showlegend":false,"x":["2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-27T00:00:00","2013-05-28T00:00:00","2013-05-29T00:00:00","2013-05-30T00:00:00","2013-05-31T00:00:00","2013-06-03T00:00:00","2013-06-04T00:00:00","2013-06-05T00:00:00","2013-06-06T00:00:00","2013-06-07T00:00:00","2013-06-10T00:00:00","2013-06-11T00:00:00","2013-06-12T00:00:00","2013-06-13T00:00:00","2013-06-14T00:00:00","2013-06-17T00:00:00","2013-06-18T00:00:00","2013-06-19T00:00:00","2013-06-20T00:00:00","2013-06-21T00:00:00","2013-06-24T00:00:00","2013-06-25T00:00:00","2013-06-26T00:00:00","2013-06-27T00:00:00","2013-06-28T00:00:00","2013-07-01T00:00:00","2013-07-02T00:00:00","2013-07-03T00:00:00","2013-07-04T00:00:00","2013-07-05T00:00:00","2013-07-08T00:00:00","2013-07-09T00:00:00","2013-07-10T00:00:00","2013-07-11T00:00:00","2013-07-12T00:00:00","2013-07-15T00:00:00","2013-07-16T00:00:00","2013-07-17T00:00:00","2013-07-18T00:00:00","2013-07-19T00:00:00","2013-07-22T00:00:00","2013-07-23T00:00:00","2013-07-24T00:00:00","2013-07-25T00:00:00","20 ...

# %%
test_size = df[df.Date.dt.year==2022].shape[0]
test_size
# Out:
# 260

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'aquamarine'
plt.rc('axes',edgecolor='white')
plt.plot(df.Date[:-test_size], df.Price[:-test_size], color='black', lw=2)
plt.plot(df.Date[-test_size:], df.Price[-test_size:], color='blue', lw=2)
plt.title('Gold Price Training and Test Sets', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training set', 'Test set'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %%
scaler = MinMaxScaler()
scaler.fit(df.Price.values.reshape(-1,1))
# Out:
# MinMaxScaler()

# %%
window_size = 60

# %%
train_data = df.Price[:-test_size]
train_data = scaler.transform(train_data.values.reshape(-1,1))

# %%
X_train = []
y_train = []

for i in range(window_size, len(train_data)):
    X_train.append(train_data[i-60:i, 0])
    y_train.append(train_data[i, 0])

# %%
test_data = df.Price[-test_size-60:]
test_data = scaler.transform(test_data.values.reshape(-1,1))

# %%
X_test = []
y_test = []

for i in range(window_size, len(test_data)):
    X_test.append(test_data[i-60:i, 0])
    y_test.append(test_data[i, 0])

# %%
X_train = np.array(X_train)
X_test  = np.array(X_test)
y_train = np.array(y_train)
y_test  = np.array(y_test)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test  = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
y_train = np.reshape(y_train, (-1,1))
y_test  = np.reshape(y_test, (-1,1))

# %%
print('X_train Shape: ', X_train.shape)
print('y_train Shape: ', y_train.shape)
print('X_test Shape:  ', X_test.shape)
print('y_test Shape:  ', y_test.shape)
# Out:
# X_train Shape:  (2263, 60, 1)
# y_train Shape:  (2263, 1)
# X_test Shape:   (260, 60, 1)
# y_test Shape:   (260, 1)

# %%
def define_model():
    input1 = Input(shape=(window_size,1))
    x = LSTM(units = 64, return_sequences=True)(input1)
    x = Dropout(0.2)(x)
    x = LSTM(units = 64, return_sequences=True)(x)
    x = Dropout(0.2)(x)
    x = LSTM(units = 64)(x)
    x = Dropout(0.2)(x)
    x = Dense(32, activation='softmax')(x)
    dnn_output = Dense(1)(x)

    model = Model(inputs=input1, outputs=[dnn_output])
    model.compile(loss='mean_squared_error', optimizer='Nadam')
    model.summary()

    return model

# %%
model = define_model()
history = model.fit(X_train, y_train, epochs=150, batch_size=32, validation_split=0.1, verbose=1)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 60, 1)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 60, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 60, 64)         │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 60, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 85,057 (332.25 KB)
#  Trainable params: 85,057 (332.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - loss: 0.0815 - val_loss: 0.0843
# Epoch 2/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 0.0180 - val_loss: 0.0381
# Epoch 3/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 0.0088 - val_loss: 0.0164
# Epoch 4/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 0.0050 - val_loss: 0.0065
# Epoch 5/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 0.0036 - val_loss: 0.0028
# Epoch 6/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.0032 - val_loss: 0.0022
# Epoch 7/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0022 - val_loss: 0.0030
# Epoch 8/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 0.0020 - val_loss: 0.0043
# Epoch 9/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0018 - val_loss: 0.0048
# Epoch 10/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 0.0017 - val_loss: 0.0033
# Epoch 11/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 0.0015 - val_loss: 0.0059
# Epoch 12/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - loss: 0.0013 - val_loss: 0.0080
# Epoch 13/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - loss: 0.0014 - val_loss: 0.0109
# Epoch 14/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 0.0013 - val_loss: 0.0035
# Epoch 15/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 76ms/step - loss: 0.0011 - val_loss: 0.0059
# Epoch 16/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 17/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 9.7529e-04 - val_loss: 0.0030
# Epoch 18/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - loss: 9.7791e-04 - val_loss: 0.0028
# Epoch 19/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 0.0010 - val_loss: 0.0029
# Epoch 20/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 9.2192e-04 - val_loss: 0.0012
# Epoch 21/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 8.6013e-04 - val_loss: 0.0036
# Epoch 22/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 61ms/step - loss: 8.7572e-04 - val_loss: 0.0031
# Epoch 23/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 7.9514e-04 - val_loss: 9.2018e-04
# Epoch 24/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 7.6488e-04 - val_loss: 0.0015
# Epoch 25/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - loss: 8.8250e-04 - val_loss: 0.0027
# Epoch 26/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 7.9429e-04 - val_loss: 0.0013
# Epoch 27/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 7.9070e-04 - val_loss: 0.0016
# Epoch 28/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 7.1788e-04 - val_loss: 0.0015
# Epoch 29/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 6.5302e-04 - val_loss: 0.0045
# Epoch 30/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 7.0153e-04 - val_loss: 9.1835e-04
# Epoch 31/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 6.7367e-04 - val_loss: 0.0013
# Epoch 32/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 7.2220e-04 - val_loss: 0.0013
# Epoch 33/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 6.3383e-04 - val_loss: 0.0012
# Epoch 34/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 5.8036e-04 - val_loss: 0.0011
# Epoch 35/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 5.9838e-04 - val_loss: 0.0042
# Epoch 36/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 6.2509e-04 - val_loss: 9.1267e-04
# Epoch 37/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 5.9206e-04 - val_loss: 0.0016
# Epoch 38/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 60ms/step - loss: 6.0894e-04 - val_loss: 0.0011
# Epoch 39/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 5.6030e-04 - val_loss: 7.6244e-04
# Epoch 40/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 5.4556e-04 - val_loss: 5.5464e-04
# Epoch 41/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 4.5826e-04 - val_loss: 7.2265e-04
# Epoch 42/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 5.4120e-04 - val_loss: 0.0015
# Epoch 43/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 5.4221e-04 - val_loss: 0.0041
# Epoch 44/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 5.4542e-04 - val_loss: 0.0011
# Epoch 45/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 5.0878e-04 - val_loss: 0.0024
# Epoch 46/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 5.4167e-04 - val_loss: 6.3500e-04
# Epoch 47/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - loss: 4.7018e-04 - val_loss: 0.0030
# Epoch 48/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 5.1021e-04 - val_loss: 0.0011
# Epoch 49/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 5.0228e-04 - val_loss: 6.7637e-04
# Epoch 50/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 4.7168e-04 - val_loss: 0.0023
# Epoch 51/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 4.4465e-04 - val_loss: 7.2466e-04
# Epoch 52/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 4.8244e-04 - val_loss: 7.9985e-04
# Epoch 53/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 5.1395e-04 - val_loss: 0.0010
# Epoch 54/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 4.2948e-04 - val_loss: 0.0014
# Epoch 55/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 4.7577e-04 - val_loss: 0.0020
# Epoch 56/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.2141e-04 - val_loss: 7.5393e-04
# Epoch 57/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.2388e-04 - val_loss: 0.0020
# Epoch 58/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 4.9423e-04 - val_loss: 8.2669e-04
# Epoch 59/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 4.9845e-04 - val_loss: 6.7961e-04
# Epoch 60/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 4.6563e-04 - val_loss: 5.8095e-04
# Epoch 61/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 4.5689e-04 - val_loss: 0.0011
# Epoch 62/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - loss: 4.5205e-04 - val_loss: 4.8990e-04
# Epoch 63/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 4.0623e-04 - val_loss: 6.5695e-04
# Epoch 64/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 4.2496e-04 - val_loss: 6.7121e-04
# Epoch 65/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 4.8423e-04 - val_loss: 8.5230e-04
# Epoch 66/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 3.4958e-04 - val_loss: 0.0013
# Epoch 67/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 4.1716e-04 - val_loss: 6.5294e-04
# Epoch 68/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 3.8582e-04 - val_loss: 6.2994e-04
# Epoch 69/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 4.1628e-04 - val_loss: 0.0023
# Epoch 70/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 3.8470e-04 - val_loss: 9.0583e-04
# Epoch 71/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - loss: 3.7365e-04 - val_loss: 0.0018
# Epoch 72/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 3.9748e-04 - val_loss: 0.0015
# Epoch 73/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 3.6582e-04 - val_loss: 0.0010
# Epoch 74/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 3.3528e-04 - val_loss: 0.0019
# Epoch 75/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 3.7693e-04 - val_loss: 0.0022
# Epoch 76/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 4.0085e-04 - val_loss: 0.0018
# Epoch 77/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 3.8817e-04 - val_loss: 0.0018
# Epoch 78/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 3.5173e-04 - val_loss: 8.6369e-04
# Epoch 79/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 3.6738e-04 - val_loss: 0.0012
# Epoch 80/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 3.4587e-04 - val_loss: 0.0027
# Epoch 81/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 3.4999e-04 - val_loss: 0.0025
# Epoch 82/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 4.3172e-04 - val_loss: 0.0022
# Epoch 83/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - loss: 3.1597e-04 - val_loss: 0.0010
# Epoch 84/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 3.2961e-04 - val_loss: 0.0011
# Epoch 85/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 3.3460e-04 - val_loss: 0.0049
# Epoch 86/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 3.6138e-04 - val_loss: 9.2804e-04
# Epoch 87/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 3.4205e-04 - val_loss: 0.0013
# Epoch 88/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 3.6318e-04 - val_loss: 0.0011
# Epoch 89/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 3.4491e-04 - val_loss: 8.2304e-04
# Epoch 90/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 3.4200e-04 - val_loss: 6.7307e-04
# Epoch 91/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 3.3884e-04 - val_loss: 0.0013
# Epoch 92/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 3.2595e-04 - val_loss: 0.0021
# Epoch 93/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 3.5932e-04 - val_loss: 0.0013
# Epoch 94/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 3.3756e-04 - val_loss: 0.0014
# Epoch 95/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - loss: 3.4907e-04 - val_loss: 6.8667e-04
# Epoch 96/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 3.4869e-04 - val_loss: 0.0012
# Epoch 97/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 3.7439e-04 - val_loss: 0.0037
# Epoch 98/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 3.8034e-04 - val_loss: 0.0011
# Epoch 99/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 3.2434e-04 - val_loss: 0.0010
# Epoch 100/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 3.2196e-04 - val_loss: 0.0010
# Epoch 101/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 3.0531e-04 - val_loss: 0.0016
# Epoch 102/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 83ms/step - loss: 3.2052e-04 - val_loss: 9.7412e-04
# Epoch 103/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 3.3174e-04 - val_loss: 0.0015
# Epoch 104/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 2.9695e-04 - val_loss: 0.0024
# Epoch 105/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 3.2365e-04 - val_loss: 0.0016
# Epoch 106/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 3.0592e-04 - val_loss: 9.3961e-04
# Epoch 107/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 71ms/step - loss: 3.3171e-04 - val_loss: 9.9965e-04
# Epoch 108/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 3.3686e-04 - val_loss: 0.0011
# Epoch 109/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 3.0226e-04 - val_loss: 9.1541e-04
# Epoch 110/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 3.6656e-04 - val_loss: 0.0018
# Epoch 111/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 2.7747e-04 - val_loss: 8.8120e-04
# Epoch 112/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 3.3919e-04 - val_loss: 7.5315e-04
# Epoch 113/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 2.8915e-04 - val_loss: 0.0019
# Epoch 114/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 3.5184e-04 - val_loss: 0.0013
# Epoch 115/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 3.2410e-04 - val_loss: 0.0018
# Epoch 116/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 3.2269e-04 - val_loss: 0.0011
# Epoch 117/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 3.4047e-04 - val_loss: 0.0024
# Epoch 118/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - loss: 3.2869e-04 - val_loss: 0.0023
# Epoch 119/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 3.3100e-04 - val_loss: 0.0033
# Epoch 120/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 3.4212e-04 - val_loss: 0.0024
# Epoch 121/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 3.2471e-04 - val_loss: 0.0022
# Epoch 122/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 3.1665e-04 - val_loss: 0.0013
# Epoch 123/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 3.0936e-04 - val_loss: 0.0011
# Epoch 124/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 3.3856e-04 - val_loss: 0.0016
# Epoch 125/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 2.9640e-04 - val_loss: 0.0012
# Epoch 126/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 3.6896e-04 - val_loss: 0.0015
# Epoch 127/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 3.1757e-04 - val_loss: 0.0017
# Epoch 128/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 3.0331e-04 - val_loss: 0.0014
# Epoch 129/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 3.0944e-04 - val_loss: 0.0019
# Epoch 130/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 3.1485e-04 - val_loss: 0.0021
# Epoch 131/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 3.3416e-04 - val_loss: 0.0013
# Epoch 132/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 3.3372e-04 - val_loss: 0.0025
# Epoch 133/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 3.0331e-04 - val_loss: 0.0022
# Epoch 134/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 2.9092e-04 - val_loss: 0.0013
# Epoch 135/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 3.7660e-04 - val_loss: 0.0011
# Epoch 136/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 70ms/step - loss: 3.1939e-04 - val_loss: 0.0026
# Epoch 137/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - loss: 2.9498e-04 - val_loss: 0.0014
# Epoch 138/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 2.7948e-04 - val_loss: 0.0021
# Epoch 139/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - loss: 2.9330e-04 - val_loss: 0.0020
# Epoch 140/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - loss: 3.5575e-04 - val_loss: 0.0015
# Epoch 141/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 2.7704e-04 - val_loss: 0.0013
# Epoch 142/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 2.8758e-04 - val_loss: 0.0018
# Epoch 143/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 3.1415e-04 - val_loss: 0.0017
# Epoch 144/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 6s 75ms/step - loss: 2.6570e-04 - val_loss: 0.0021
# Epoch 145/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - loss: 3.4031e-04 - val_loss: 0.0017
# Epoch 146/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 72ms/step - loss: 2.6972e-04 - val_loss: 0.0028
# Epoch 147/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 2.9888e-04 - val_loss: 0.0025
# Epoch 148/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 3.0217e-04 - val_loss: 8.3197e-04
# Epoch 149/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 5s 64ms/step - loss: 2.6941e-04 - val_loss: 0.0014
# Epoch 150/150
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - loss: 2.5555e-04 - val_loss: 0.0012

# %%
result = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 9.2802e-04
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step

# %%
MAPE = mean_absolute_percentage_error(y_test, y_pred)
Accuracy = 1 - MAPE

# %%
print("Test Loss:", result)
print("Test MAPE:", MAPE)
print("Test Accuracy:", Accuracy)
# Out:
# Test Loss: 0.0010913796722888947
# Test MAPE: 0.03686008523810276
# Test Accuracy: 0.9631399147618972

# %%
y_test_true = scaler.inverse_transform(y_test)
y_test_pred = scaler.inverse_transform(y_pred)

# %%
plt.figure(figsize=(15, 6), dpi=150)
plt.rcParams['axes.facecolor'] = 'aquamarine'
plt.rc('axes',edgecolor='white')
plt.plot(df['Date'].iloc[:-test_size], scaler.inverse_transform(train_data), color='black', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_true, color='blue', lw=2)
plt.plot(df['Date'].iloc[-test_size:], y_test_pred, color='red', lw=2)
plt.title('Gold Price Prediction Model Performance', fontsize=15)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Price', fontsize=12)
plt.legend(['Training Data', 'Actual Test Data', 'Predicted Test Data'], loc='upper left', prop={'size': 15})
plt.grid(color='white')
plt.show()

# %%
pip install dash
# Out:
# Collecting dash
#   Downloading dash-3.0.4-py3-none-any.whl.metadata (10 kB)
# Collecting Flask<3.1,>=1.0.4 (from dash)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.1 (from dash)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from dash) (5.24.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from dash) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash) (4.14.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from dash) (75.2.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (8.2.1)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash) (1.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->dash) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->dash) (24.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from Werkzeug<3.1->dash) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->dash) (3.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->dash) (2025.4.26)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from retrying->dash) (1.17.0)
# Downloading dash-3.0.4-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 31.7 MB/s eta 0:00:00
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 7.1 MB/s eta 0:00:00
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 17.7 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Installing collected packages: Werkzeug, retrying, Flask, dash
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 3.1.3
#     Uninstalling Werkzeug-3.1.3:
#       Successfully uninstalled Werkzeug-3.1.3
#   Attempting uninstall: Flask
#     Found existing installation: Flask 3.1.1
#     Uninstalling Flask-3.1.1:
#       Successfully uninstalled Flask-3.1.1
# Successfully installed Flask-3.0.3 Werkzeug-3.0.6 dash-3.0.4 retrying-1.3.4

# %%
import dash
from dash import dcc, html
import plotly.express as px
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# Inverse transform the scaled data
train_data_original = scaler.inverse_transform(train_data)
y_test_true_original = scaler.inverse_transform(y_test_true.reshape(-1, 1))
y_test_pred_original = scaler.inverse_transform(y_test_pred.reshape(-1, 1))

# Creating a Dash web application
app = dash.Dash(__name__)

# Define the layout of the web application
app.layout = html.Div([
    html.H1("Performance of the Gold Price Prediction Model"),

    # Line plot for Training Data
    dcc.Graph(
        figure=px.line(x=df['Date'].iloc[:-test_size], y=train_data_original.flatten(),
                       labels={'x': 'Date', 'y': 'Price'},
                       title='Training Data',
                       template='plotly_dark',
                       line_shape='linear',
                       markers=True,
                       ),
    ),

    # Line plot for Actual Test Data and Predicted Test Data
    dcc.Graph(
        figure=px.line(x=df['Date'].iloc[-test_size:], y=[y_test_true_original.flatten(), y_test_pred_original.flatten()],
                       labels={'x': 'Date', 'y': 'Price'},
                       title='Actual vs. Predicted Test Data',
                       template='plotly_dark',
                       line_shape='linear',
                       markers=True,
                       ),
    )
])

# Running the web application
if __name__ == '__main__':
    app.run(debug=True, port=8051)
